# %%
import matplotlib.pyplot as plt 
import numpy as np  
import pandas as pd  
import seaborn as sns  
import gower
from scipy.cluster.hierarchy import cophenet, linkage, dendrogram  # to perform cluster analysis
from scipy.spatial.distance import pdist, squareform  # to calculate distances and convert between condensed and square forms of a distance matrix
from sklearn.preprocessing import MinMaxScaler  # To standardize our data before clustering

# %%
subset_df = pd.read_csv("/home/jovyan/my_dataset.tsv", sep="\t")
subset_df.head()
subset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   subjectkey                  1000 non-null   object
#  1   interview_date              1000 non-null   object
#  2   interview_age               1000 non-null   int64
#  3   sex                         1000 non-null   object
#  4   site_id_l                   1000 non-null   object
#  5   anthroheightcalc            1000 non-null   float64
#  6   anthroweightcalc            1000 non-null   float64
#  7   neighborhood_crime_y        1000 non-null   float64
#  8   ksads_ptsd_raw_763_p        1000 non-null   float64
#  9   ksads_8_29_t                1000 non-null   int64
#  10  ksads_13_929_t              1000 non-null   int64
#  11  fes_y_ss_fc_pr              1000 non-null   float64
#  12  rsfmri_c_ngd_sa_ngd_cgc     1000 non-null   float64
#  13  rsfmri_c_ngd_sa_ngd_ca      1000 non-null   float64
#  14  rsfmri_c_ngd_sa_ngd_dt      1000 non-null   float64
#  15  rsfmri_c_ngd_sa_ngd_dla     1000 non-null   float64
#  16  rsfmri_c_ngd_sa_ngd_fo      1000 non-null   float64
#  17  rsfmri_c_ngd_sa_ngd_rspltp  1000 non-null   float64
#  18  rsfmri_c_ngd_sa_ngd_vta     1000 non-null   float64
#  19  mri_info_manufacturer       1000 non-null   object
# dtypes: float64(12), int64(3), object(5)
# memory usage: 156.4+ KB

# %%
type(subset_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   subjectkey                  1000 non-null   object
#  1   interview_date              1000 non-null   object
#  2   interview_age               1000 non-null   int64
#  3   sex                         1000 non-null   object
#  4   site_id_l                   1000 non-null   object
#  5   anthroheightcalc            1000 non-null   float64
#  6   anthroweightcalc            1000 non-null   float64
#  7   neighborhood_crime_y        1000 non-null   float64
#  8   ksads_ptsd_raw_763_p        1000 non-null   float64
#  9   ksads_8_29_t                1000 non-null   int64
#  10  ksads_13_929_t              1000 non-null   int64
#  11  fes_y_ss_fc_pr              1000 non-null   float64
#  12  rsfmri_c_ngd_sa_ngd_cgc     1000 non-null   float64
#  13  rsfmri_c_ngd_sa_ngd_ca      1000 non-null   float64
#  14  rsfmri_c_ngd_sa_ngd_dt      1000 non-null   float64
#  15  rsfmri_c_ngd_sa_ngd_dla     1000 non-null   float64
#  16  rsfmri_c_ngd_sa_ngd_fo      1000 non-null   float64
#  17  rsfmri_c_ngd_sa_ngd_rspltp  1000 non-null   float64
#  18  rsfmri_c_ngd_sa_ngd_vta     1000 non-null   float64
#  19  mri_info_manufacturer       1000 non-null   object
# dtypes: float64(12), int64(3), object(5)
# memory usage: 156.4+ KB
# NoneType

# %%
subset_df["interview_date"] = pd.to_datetime(subset_df["interview_date"])

# %%
subset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   subjectkey                  1000 non-null   object
#  1   interview_date              1000 non-null   datetime64[ns]
#  2   interview_age               1000 non-null   int64
#  3   sex                         1000 non-null   object
#  4   site_id_l                   1000 non-null   object
#  5   anthroheightcalc            1000 non-null   float64
#  6   anthroweightcalc            1000 non-null   float64
#  7   neighborhood_crime_y        1000 non-null   float64
#  8   ksads_ptsd_raw_763_p        1000 non-null   float64
#  9   ksads_8_29_t                1000 non-null   int64
#  10  ksads_13_929_t              1000 non-null   int64
#  11  fes_y_ss_fc_pr              1000 non-null   float64
#  12  rsfmri_c_ngd_sa_ngd_cgc     1000 non-null   float64
#  13  rsfmri_c_ngd_sa_ngd_ca      1000 non-null   float64
#  14  rsfmri_c_ngd_sa_ngd_dt      1000 non-null   float64
#  15  rsfmri_c_ngd_sa_ngd_dla     1000 non-null   float64
#  16  rsfmri_c_ngd_sa_ngd_fo      1000 non-null   float64
#  17  rsfmri_c_ngd_sa_ngd_rspltp  1000 non-null   float64
#  18  rsfmri_c_ngd_sa_ngd_vta     1000 non-null   float64
#  19  mri_info_manufacturer       1000 non-null   object
# dtypes: datetime64[ns](1), float64(12), int64(3), object(4)
# memory usage: 156.4+ KB

# %%
categ_df = subset_df.select_dtypes(include=["object"])
categ_df.head()
# Out:
#          subjectkey sex site_id_l mri_info_manufacturer
# 0  NDAR_INVPCG19NKC   M    site02               SIEMENS
# 1  NDAR_INVZWWDT1TG   F    site13    GE MEDICAL SYSTEMS
# 2  NDAR_INVLZNG6R0U   F    site10    GE MEDICAL SYSTEMS
# 3  NDAR_INVUGP7XGXD   M    site11               SIEMENS
# 4  NDAR_INVJ136TW5A   F    site16               SIEMENS

# %%
categ_features = pd.get_dummies(categ_df, drop_first=True)

# %%
categ_features.shape
# Out:
# (1000, 1023)

# %%
num_df = subset_df.select_dtypes(include=["float64", "int64"])
num_df.head()
# Out:
#    interview_age  anthroheightcalc  anthroweightcalc  neighborhood_crime_y  \
# 0            118             55.50             72.00                   5.0
# 1            118             56.75             90.00                   5.0
# 2            121             57.50             79.25                   4.0
# 3            118             52.25             63.50                   3.0
# 4            127             51.50             59.00                   5.0
#
#    ksads_ptsd_raw_763_p  ksads_8_29_t  ksads_13_929_t  fes_y_ss_fc_pr  \
# 0                   0.0             0             555             0.0
# 1                   0.0             0             555             1.0
# 2                   0.0             0             555             3.0
# 3                   0.0             0             555             0.0
# 4                   0.0             0             555             1.0
#
#    rsfmri_c_ngd_sa_ngd_cgc  rsfmri_c_ngd_sa_ngd_ca  rsfmri_c_ngd_sa_ngd_dt  \
# 0                 0.148009               -0.094787                0.076102
# 1                 0.057800                0.198565                0.237472
# 2                 0.082639                0.084297                0.100836
# 3                 0.127570                0.058124                0.121959
# 4                 0.294148               -0.162451                0.110895
#
#    rsfmri_c_ngd_sa_ngd_dla  rsfmri_c_ngd_sa_ngd_fo  \
# 0                 0.009678                0.084188
# 1                -0.136648                0.140575
# 2                -0.019320                0.042764
# 3                -0.051479                0.019095
# 4                 0.111905               -0.016870
#
#    rsfmri_c_ngd_sa_ngd_rspltp  rsfmri_c_ngd_sa_ngd_vta
# 0                   -0.147260                 0.120612
# 1                    0.020615                 0.215537
# 2                   -0.067097                 0.110973
# 3                    0.104671                 0.120696
# 4                   -0.262540                 0.230740

# %%
minmax = MinMaxScaler(feature_range=(0, 1))

num_features = pd.DataFrame(
    minmax.fit_transform(num_df),
    index=num_df.index,
    columns=num_df.columns
)

# %%
df_scaled = pd.concat([num_features, categ_features], axis="columns")

# Confirm that all data lies between zero and one.
print(f"Data min, max: {df_scaled.min().min(), df_scaled.max().max()}")
# Out:
# Data min, max: (0.0, 1.0)

# %%
df_scaled.shape
# Out:
# (1000, 1038)

# %%
Y = gower.gower_matrix(df_scaled.T).astype(np.float64)

# %%
Y
# Out:
# array([[0.        , 0.32046324, 0.30759794, ..., 0.47      , 0.46948001,
#         0.49992001],
#        [0.32046324, 0.        , 0.52208018, ..., 0.74387765, 0.68328083,
#         0.43951648],
#        [0.30759794, 0.52208018, 0.        , ..., 0.22600701, 0.29767254,
#         0.55949801],
#        ...,
#        [0.47      , 0.74387765, 0.22600701, ..., 0.        , 0.131     ,
#         0.61799997],
#        [0.46948001, 0.68328083, 0.29767254, ..., 0.131     , 0.        ,
#         0.74299997],
#        [0.49992001, 0.43951648, 0.55949801, ..., 0.61799997, 0.74299997,
#         0.        ]])

# %%
plt.matshow(Y)

# %%
dist = squareform(Y) # Upper triangular matrix

# %%
Z = linkage(dist, method="complete", optimal_ordering=True)
Z[:6,:]
# Out:
# array([[6.00000000e+00, 1.09000000e+02, 1.00000005e-03, 2.00000000e+00],
#        [1.94000000e+02, 1.50000000e+01, 2.00000009e-03, 2.00000000e+00],
#        [3.46000000e+02, 1.60000000e+01, 2.00000009e-03, 2.00000000e+00],
#        [1.70000000e+01, 4.17000000e+02, 2.00000009e-03, 2.00000000e+00],
#        [1.80000000e+01, 5.77000000e+02, 2.00000009e-03, 2.00000000e+00],
#        [6.94000000e+02, 1.90000000e+01, 2.00000009e-03, 2.00000000e+00]])

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))
dn = dendrogram(
    Z,
    ax=ax,
    orientation="top",
    distance_sort='descending',
    show_leaf_counts=True,
)

# `dn["ivl"] stores a list of the feature indices in the order they appear on the x axis.
# Let's label the x-axis using the actual feature names rather than the indices
_ = ax.set_xticklabels(
    [list(df_scaled.columns)[int(i)] for i in dn["ivl"]],
    rotation=90,
    fontsize=16,
)

yticks = np.linspace(0.0, 0.8, 5)
_ = ax.set_yticks(yticks)
_ = ax.set_yticklabels([round(y, 1) for y in yticks], fontsize=16)

# %%
_ = sns.pairplot(
    subset_df,
    vars=["fes_y_ss_fc_pr", "ksads_13_929_t", "ksads_ptsd_raw_763_p", "ksads_8_29_t"]
)

# %%
c, coph_dists = cophenet(Z, pdist(df_scaled.T.values, "cityblock"))
print(f"Cophenetic correlation coefficient: {c}")
# Out:
# Cophenetic correlation coefficient: 0.9739070176016436

# %%
_ = subset_df[subset_df["mri_info_manufacturer"] == "Philips Medical Systems"]["site_id_l"].hist()
